# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
import os
import numpy as np
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import FloatType
from pyspark.ml.clustering import KMeans
from pyspark.ml.feature import VectorAssembler, HashingTF, IDF, Tokenizer
from pyspark.sql.functions import explode, split
from pyspark.ml.linalg import Vectors
from pyspark.ml.linalg import DenseVector, SparseVector
from pyspark.sql.functions import udf
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
spark = SparkSession.builder.appName("text to csv").getOrCreate()

# %%
rdd = spark.sparkContext.wholeTextFiles("TextFiles/*.txt", use_unicode=True)

# convert rdd to dataframe
df = rdd.toDF(["filename", "text"])

# split the text column into separate columns
df = df.select(split("text", "\n").alias("columns"))

# select each column and add them to the dataframe
df = df.selectExpr("columns[0] as link", "columns[1] as heading", "columns[2] as time", "columns[3] as news")

# show the dataframe
df.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+
# |                link|             heading|                time|                news|
# +--------------------+--------------------+--------------------+--------------------+
# |https://edition.c...|‘Nothing left to ...|2023-05-07 22:34:...|The head of the W...|
# |https://edition.c...|Loaf-size mission...|2023-05-07 21:06:...|A new mission des...|
# |https://edition.c...|Wagner boss sugge...|2023-05-07 18:39:...|Yevgeny Prigozhin...|
# |https://edition.c...|Fire kills at lea...|2023-05-07 16:32:...|A fire in a small...|
# |https://edition.c...|The lady in blue,...|2023-05-07 16:29:...|The coronation of...|
# |https://edition.c...|Gold mine fire in...|2023-05-07 13:14:...|A fire in a small...|
# |https://edition.c...|‘A Trump tribute ...|2023-05-07 23:50:...|Late last year, a...|
# |https://edition.c...|Arab League readm...|2023-05-07 12:24:...|The Arab League h...|
# |https://edition.c...|UK police face ba...|2023-05-07 08:05:...|A senior UK gover...|
# |https://edition.c...|Analysis: Ukraine...|2023-05-07 06:34:...|Ukraine’s asserti...|
# |https://edition.c...|Over 50 dead, hun...|2023-05-07 06:34:...|Ethnic violence i...|
# |https://edition.c...|Russian director ...|2023-05-07 05:50:...|An acclaimed thea...|
# |https://edition.c...|Prince Harry is a...|2023-05-07 05:43:...|It was just a sho...|
# |https://edition.c...|French minister’s...|2023-05-07 04:14:...|France’s finance ...|
# |https://edition.c...|Russian authoriti...|2023-05-07 03:21:...|Russian-appointed...|
# |https://edition.c...|In shock and mour...|2023-05-05 11:07:...|Serbians are reel...|
# |https://edition.c...|Putin faces a del...|2023-05-05 09:16:...|“These are someon...|
# |https://edition.c...|UK’s Chief Rabbi ...|2023-05-05 06:57:...|Britain’s Chief R...|
# |https://edition.c...|Suspect arrested ...|2023-05-05 06:30:...|A man suspected o...|
# |https://edition.c...|US rejects Russia...|2023-05-05 05:44:...|The United States...|
# +--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
df = df.toPandas()
df.dropna(inplace = True)

# %%
cwd = os.getcwd()

# %%
txt_files = os.listdir('labeledData')
articles = []
labels = []
for file in txt_files:
    with open(f'labeledData/{file}', encoding='utf-8') as f:
        try:
            text = f.read()
            lines = text.split('\n')
            article = lines[-1]
            label = lines[1][1:]
            articles.append(article)
            labels.append(label)
        except:
            continue

# %%
articles_df = pd.DataFrame(np.array([articles, labels]).T, columns=['article', 'label'])

# %%
articles_df
# Out:
#                                                article     label
# 0    Boston-based travelers, you’re in for a treat....  business
# 1    Nordstrom. Walmart. Whole Foods. Starbucks. CV...  business
# 2    An ex-ByteDance employee claimed he was wrongf...  business
# 3    Pickleball is coming to your local mall, repla...  business
# 4    Leaders in Washington are running out of time ...  business
# ..                                                 ...       ...
# 378  The world’s oldest dog is living it up in his ...     world
# 379  Loonkiito, possibly one of the oldest lions in...     world
# 380  “People say I’m a funny guy,” Finnish rapper K...     world
# 381  Germany announced on Saturday that it would su...     world
# 382  Palestinian militants launched rockets towards...     world
#
# [383 rows x 2 columns]

# %%
label_dict = {'business': 0,
               'entertainment': 1,
               'health': 2,
               'politics': 3,
               'sport': 4,
               'style': 5,
               'travel': 6,
               'world': 7}

# %%
articles_df['label'] = articles_df['label'].apply(lambda x: label_dict[x])

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
def preprocess(text):
    tokens = word_tokenize(text.lower())
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    return " ".join(tokens)

# %%
articles_df['article_preprocessed'] = articles_df['article'].apply(preprocess)

# %%
df = df.applymap(lambda x: x.replace('\r', '').strip())
df.dropna(inplace = True)

# %%
X_train, Y_Train = articles_df['article_preprocessed'], articles_df['label']

vectorizer = CountVectorizer()
X_train_vectorized = vectorizer.fit_transform(X_train)

# %%
df_copy = df.copy()

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(X_train_vectorized, Y_Train)
df_copy['news'] = df_copy['news'].apply(preprocess)
df_copy['category'] = model.predict(vectorizer.transform(df_copy['news'] ))

df['category'] = df_copy['category'].apply(lambda x: list(label_dict.keys())\
                                      [list(label_dict.values()).index(x)])

# %%
df
# Out:
#                                                    link  \
# 0     https://edition.cnn.com/2023/05/06/europe/wagn...
# 1     https://edition.cnn.com/2023/05/07/world/nasa-...
# 2     https://edition.cnn.com/2023/05/07/europe/prig...
# 3     https://edition.cnn.com/2023/05/07/americas/pe...
# 4     https://edition.cnn.com/2023/05/06/uk/coronati...
# ...                                                 ...
# 1094  https://edition.cnn.com/2023/05/02/sport/james...
# 1095  https://edition.cnn.com/2022/11/17/football/qa...
# 1096  https://edition.cnn.com/2022/05/11/sport/zhou-...
# 1097  https://edition.cnn.com/2022/07/25/sport/black...
# 1098  https://edition.cnn.com/2022/06/21/sport/briti...
#
#                                                 heading  \
# 0     ‘Nothing left to grind the meat with’: Wagner ...
# 1     Loaf-size mission launches to improve hurrican...
# 2     Wagner boss suggests his forces may stay in Ba...
# 3          Fire kills at least 27 in Peruvian gold mine
# 4     The lady in blue, vanishing princes and the cr...
# ...                                                 ...
# 1094  James Harden scores 45 points to lift Joel Emb...
# 1095  ‘Our dreams never came true.’ These men helped...
# 1096  She apologized for verbally abusing an Olympic...
# 1097  Meet the Black women pushing for equality in s...
# 1098  ‘I had PTSD’: Culture of abuse in British gymn...
#
#                             time  \
# 0            2023-05-07 22:34:00
# 1            2023-05-07 21:06:00
# 2            2023-05-07 18:39:00
# 3            2023-05-07 16:32:00
# 4            2023-05-07 16:29:00
# ...                          ...
# 1094         2023-05-02 05:57:00
# 1095  04:30 PM, Sun May 14, 2023
# 1096         2022-05-12 03:45:00
# 1097  04:30 PM, Sun May 14, 2023
# 1098  04:30 PM, Sun May 14, 2023
#
#                                                    news category
# 0     The head of the Wagner private military compan...    world
# 1     A new mission designed to improve hurricane fo...    world
# 2     Yevgeny Prigozhin, head of the Wagner mercenar...    world
# 3     A fire in a small gold mine in southern Peru h...    world
# 4     The coronation of King Charles III on Saturday...    style
# ...                                                 ...      ...
# 1094  Expectations were low for the Philadelphia 76e...    sport
# 1095  Kamal was standing outside a shop with other m...    sport
# 1096  For Lisa Wright, an elite-level diving judge f...    sport
# 1097  Omie Dale has fond memories of splashing in th...    sport
# 1098  For Claire Heafford, the abuse she says she su...    sport
#
# [1098 rows x 5 columns]

# %%
df.to_csv("data.csv", index = False, mode = 'a')
